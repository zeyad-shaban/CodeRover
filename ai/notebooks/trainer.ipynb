# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
cap = cv2.VideoCapture("./data/VID_20251216_142001.mp4")

# %%
cap.set(cv2.CAP_PROP_POS_FRAMES, 300)
ret, frame = cap.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

plt.imshow(frame)
